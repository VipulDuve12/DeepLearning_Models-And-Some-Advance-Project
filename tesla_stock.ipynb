# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
data = pd.read_csv('/content/TSLA.csv')

# %%
data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29   19.000000   25.000000   17.540001   23.889999   23.889999
# 1     2010-06-30   25.790001   30.420000   23.299999   23.830000   23.830000
# 2     2010-07-01   25.000000   25.920000   20.270000   21.959999   21.959999
# 3     2010-07-02   23.000000   23.100000   18.709999   19.200001   19.200001
# 4     2010-07-06   20.000000   20.000000   15.830000   16.110001   16.110001
# ...          ...         ...         ...         ...         ...         ...
# 2411  2020-01-28  568.489990  576.809998  558.080017  566.900024  566.900024
# 2412  2020-01-29  575.690002  589.799988  567.429993  580.989990  580.989990
# 2413  2020-01-30  632.419983  650.880005  618.000000  640.809998  640.809998
# 2414  2020-01-31  640.000000  653.000000  632.520020  650.570007  650.570007
# 2415  2020-02-03  673.690002  786.140015  673.520020  780.000000  780.000000
#
#         Volume
# 0     18766300
# ...

# %%
data.plot.line(x = 'Date',y='Close',figsize=(16,6),rot=45)
# Out:
# <Axes: xlabel='Date'>

# %%
data.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
data.index
# Out:
# RangeIndex(start=0, stop=2416, step=1)

# %%
# making the new variable with next day opening prize.
data['Next_Day'] = data['Close'].shift(-1)

# %%
data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29   19.000000   25.000000   17.540001   23.889999   23.889999
# 1     2010-06-30   25.790001   30.420000   23.299999   23.830000   23.830000
# 2     2010-07-01   25.000000   25.920000   20.270000   21.959999   21.959999
# 3     2010-07-02   23.000000   23.100000   18.709999   19.200001   19.200001
# 4     2010-07-06   20.000000   20.000000   15.830000   16.110001   16.110001
# ...          ...         ...         ...         ...         ...         ...
# 2411  2020-01-28  568.489990  576.809998  558.080017  566.900024  566.900024
# 2412  2020-01-29  575.690002  589.799988  567.429993  580.989990  580.989990
# 2413  2020-01-30  632.419983  650.880005  618.000000  640.809998  640.809998
# 2414  2020-01-31  640.000000  653.000000  632.520020  650.570007  650.570007
# 2415  2020-02-03  673.690002  786.140015  673.520020  780.000000  780.000000
#
#         Volume    Next_Day
# ...

# %%
data['Target'] = data['Next_Day'] > data['Close']

# %%
data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29   19.000000   25.000000   17.540001   23.889999   23.889999
# 1     2010-06-30   25.790001   30.420000   23.299999   23.830000   23.830000
# 2     2010-07-01   25.000000   25.920000   20.270000   21.959999   21.959999
# 3     2010-07-02   23.000000   23.100000   18.709999   19.200001   19.200001
# 4     2010-07-06   20.000000   20.000000   15.830000   16.110001   16.110001
# ...          ...         ...         ...         ...         ...         ...
# 2411  2020-01-28  568.489990  576.809998  558.080017  566.900024  566.900024
# 2412  2020-01-29  575.690002  589.799988  567.429993  580.989990  580.989990
# 2413  2020-01-30  632.419983  650.880005  618.000000  640.809998  640.809998
# 2414  2020-01-31  640.000000  653.000000  632.520020  650.570007  650.570007
# 2415  2020-02-03  673.690002  786.140015  673.520020  780.000000  780.000000
#
#         Volume    Next_Day  Target
# ...

# %%
data['Target'] = data['Target'].astype(int)

# %%
data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29   19.000000   25.000000   17.540001   23.889999   23.889999
# 1     2010-06-30   25.790001   30.420000   23.299999   23.830000   23.830000
# 2     2010-07-01   25.000000   25.920000   20.270000   21.959999   21.959999
# 3     2010-07-02   23.000000   23.100000   18.709999   19.200001   19.200001
# 4     2010-07-06   20.000000   20.000000   15.830000   16.110001   16.110001
# ...          ...         ...         ...         ...         ...         ...
# 2411  2020-01-28  568.489990  576.809998  558.080017  566.900024  566.900024
# 2412  2020-01-29  575.690002  589.799988  567.429993  580.989990  580.989990
# 2413  2020-01-30  632.419983  650.880005  618.000000  640.809998  640.809998
# 2414  2020-01-31  640.000000  653.000000  632.520020  650.570007  650.570007
# 2415  2020-02-03  673.690002  786.140015  673.520020  780.000000  780.000000
#
#         Volume    Next_Day  Target
# ...

# %%
data.dropna()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29   19.000000   25.000000   17.540001   23.889999   23.889999
# 1     2010-06-30   25.790001   30.420000   23.299999   23.830000   23.830000
# 2     2010-07-01   25.000000   25.920000   20.270000   21.959999   21.959999
# 3     2010-07-02   23.000000   23.100000   18.709999   19.200001   19.200001
# 4     2010-07-06   20.000000   20.000000   15.830000   16.110001   16.110001
# ...          ...         ...         ...         ...         ...         ...
# 2410  2020-01-27  541.989990  564.440002  539.280029  558.020020  558.020020
# 2411  2020-01-28  568.489990  576.809998  558.080017  566.900024  566.900024
# 2412  2020-01-29  575.690002  589.799988  567.429993  580.989990  580.989990
# 2413  2020-01-30  632.419983  650.880005  618.000000  640.809998  640.809998
# 2414  2020-01-31  640.000000  653.000000  632.520020  650.570007  650.570007
#
#         Volume    Next_Day  Target
# ...

# %%
predectors = ['Open','High','Low','Close','Volume']

# train test split
train = data.iloc[:-500]
test = data.iloc[-500:]

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators=100,min_samples_split=200,random_state=1)

# %%
model.fit(train[predectors],train['Target'])
# Out:
# RandomForestClassifier(min_samples_split=200, random_state=1)

# %%
from sklearn.metrics import precision_score

# %%
pred = model.predict(test[predectors])

# %%
pred = pd.Series(pred,index=test.index)

# %%
score = precision_score(test['Target'],pred)

# %%
score
# Out:
# 0.4843205574912892

# %%
graph = pd.concat([test['Target'],pred],axis=1)

# %%
# orange lines are our predicted value and blue is actual happening....
graph.plot()
# Out:
# <Axes: >

# %%
# as my prediction is 50 percent correct i have to increase it.....

# %%
def prediction(train,test,predectors,model):
  model.fit(train[predectors],train['Target'])
  pred = model.predict(test[predectors])
  pred = pd.Series(pred,index=test.index,name='Predictions')
  graph = pd.concat([test['Target'],pred],axis=1)
  return graph

# %%
def backtest(data1,model,predectors,start=1500,step=250):
  all_predictions = []
  for i in range(start,data.shape[0],step):
    train = data.iloc[0:i].copy()
    test = data.iloc[i:(i+step)].copy()
    predictions = prediction(train,test,predectors,model)
    all_predictions.append(predictions)
  return pd.concat(all_predictions)

# %%
predictions = backtest(data,model,predectors)

# %%
precision_score(predictions['Target'],predictions['Predictions'])
# Out:
# 0.5666666666666667

# %%
combined = pd.concat([data,predictions['Predictions']],axis=1)

# %%
combined.plot()
# Out:
# <Axes: >
